# %%
from mmdet.apis import init_detector
from mmdet.apis import inference_detector
# from mmdet.apis import show_result

# %%
import mmcv
import os
import numpy as np
from mmcv.runner import load_checkpoint
from mmdet.models import build_detector
from mmdet.apis import init_detector, inference_detector

# %%
# !python ./tools/test.py  \
  /root/Large-Selective-Kernel-Network/configs/lsknet/lsk_s_fpn_1x_dota_le90.py\
  /root/Large-Selective-Kernel-Network/epoch_7.pth --format-only \
  --eval-options submission_dir=work_dirs/Task1_results
# Out:
# /root/miniconda3/lib/python3.8/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# ./tools/test.py:123: UserWarning: `mp_start_method` in `cfg` is set to `spawn` to use CUDA with multiprocessing when formatting output result.
#   warnings.warn(
# file_path /root/Large-Selective-Kernel-Network/data/split_ss_dota/test/images
# /root/miniconda3/lib/python3.8/site-packages/mmdet/models/dense_heads/anchor_head.py:116: UserWarning: DeprecationWarning: `num_anchors` is deprecated, for consistency or also use `num_base_priors` instead
#   warnings.warn('DeprecationWarning: `num_anchors` is deprecated, '
# ...

# %%
# !python /root/Large-Selective-Kernel-Network/demo/image_demo.py \
  /root/autodl-tmp/images/1.bmp \
  /root/Large-Selective-Kernel-Network/configs/lsknet/lsk_s_fpn_1x_dota_le90.py \
  /root/Large-Selective-Kernel-Network/epoch_7.pth \
  --out-file /root/autodl-tmp/test_result
# Out:
# /root/miniconda3/lib/python3.8/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Traceback (most recent call last):
#   File "/root/Large-Selective-Kernel-Network/demo/image_demo.py", line 45, in <module>
#     main(args)
#   File "/root/Large-Selective-Kernel-Network/demo/image_demo.py", line 30, in main
#     model = init_detector(args.config, args.checkpoint, device=args.device)
#   File "/root/miniconda3/lib/python3.8/site-packages/mmdet/apis/inference.py", line 44, in init_detector
#     model = build_detector(config.model, test_cfg=config.get('test_cfg'))
# ...

# %%
cd /root/Large-Selective-Kernel-Network
# Out:
# /root/Large-Selective-Kernel-Network

# %%
# !python tools/data/dota/split/img_split.py --base-json \
  tools/data/dota/split/split_configs/ss_test.json
# Out:
# Loading original data!!!
# Starting loading DOTA dataset information.
# Finishing loading DOTA, get 1818 iamges, using 0.085s.
# Start splitting images!!!
# 2023-06-15 10:15:30,766 - (0.1% 1:1818) - Filename: 14168.bmp - width: 1024  - height: 1024  - Objects: 0     - Patches: 1
# 2023-06-15 10:15:30,767 - (0.1% 2:1818) - Filename: 21782.bmp - width: 1024  - height: 1024  - Objects: 0     - Patches: 1
# 2023-06-15 10:15:30,768 - (0.2% 3:1818) - Filename: 15264.bmp - width: 1024  - height: 1024  - Objects: 0     - Patches: 1
# 2023-06-15 10:15:30,769 - (0.2% 4:1818) - Filename: 2996.bmp - width: 1024  - height: 1024  - Objects: 0     - Patches: 1
# 2023-06-15 10:15:30,771 - (0.3% 5:1818) - Filename: 27811.bmp - width: 1024  - height: 1024  - Objects: 0     - Patches: 1
# 2023-06-15 10:15:30,775 - (0.3% 6:1818) - Filename: 15521.bmp - width: 1024  - height: 1024  - Objects: 0     - Patches: 1
# ...
